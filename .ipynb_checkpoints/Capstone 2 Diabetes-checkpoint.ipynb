# %% [markdown]
# # Data Science Problem

# %% [markdown]
# # Imports

# %%
# !pip install dataprep

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from dataprep.datasets import load_dataset
from dataprep.eda import create_report

# %% [markdown]
# # Load Data Set

# %%
diabetes_class = pd.read_excel(r'C:\Users\ashle\OneDrive\Documents\GitHub\Capstone-2\Diabetes_Classification.xlsx', index_col=0)

# %%
diabetes_data = pd.read_csv(r'C:\Users\ashle\OneDrive\Documents\GitHub\Capstone-2\diabetes.csv')

# %%
diabetes_registry = pd.read_csv(r'C:\Users\ashle\OneDrive\Documents\GitHub\Capstone-2\Diabetes Registry.CSV - Introduction to Biomedical Data Science.csv')

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        403 non-null    int64
#  1   chol      402 non-null    float64
#  2   stab.glu  403 non-null    int64
#  3   hdl       402 non-null    float64
#  4   ratio     402 non-null    float64
#  5   glyhb     390 non-null    float64
#  6   location  403 non-null    object
#  7   age       403 non-null    int64
#  8   gender    403 non-null    object
#  9   height    398 non-null    float64
#  10  weight    402 non-null    float64
#  11  frame     391 non-null    object
#  12  bp.1s     398 non-null    float64
#  13  bp.1d     398 non-null    float64
#  14  bp.2s     141 non-null    float64
#  15  bp.2d     141 non-null    float64
#  16  waist     401 non-null    float64
#  17  hip       401 non-null    float64
#  18  time.ppn  400 non-null    float64
# ...

# %%
diabetes_data.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 0   121.0  medium  118.0   59.0    NaN    NaN   29.0  38.0     720.0
# 1   218.0   large  112.0   68.0    NaN    NaN   46.0  48.0     360.0
# 2   256.0   large  190.0   92.0  185.0   92.0   49.0  57.0     180.0
# 3   119.0   large  110.0   50.0    NaN    NaN   33.0  38.0     480.0
# 4   183.0  medium  138.0   80.0    NaN    NaN   44.0  41.0     300.0

# %%
diabetes_registry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        390 non-null    int64
#  1   chol      389 non-null    float64
#  2   stab.glu  390 non-null    int64
#  3   hdl       389 non-null    float64
#  4   ratio     389 non-null    float64
#  5   glyhb     390 non-null    float64
#  6   Location  390 non-null    object
#  7   Age       390 non-null    int64
#  8   Gender    390 non-null    object
#  9   Height    387 non-null    float64
#  10  Weight 1  390 non-null    int64
#  11  Weight 2  390 non-null    int64
#  12  frame     379 non-null    object
#  13  bp.1s     385 non-null    float64
#  14  bp.1d     385 non-null    float64
#  15  bp.2s     138 non-null    float64
#  16  bp.2d     138 non-null    float64
#  17  waist     388 non-null    float64
#  18  hip       388 non-null    float64
#  19  time.ppn  387 non-null    float64
# ...

# %%
diabetes_registry.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    Location  Age  Gender  Height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    Weight 1  Weight 2   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  \
# 0       121       119  medium  118.0   59.0    NaN    NaN   29.0  38.0
# 1       218       218   large  112.0   68.0    NaN    NaN   46.0  48.0
# 2       256       243   large  190.0   92.0  185.0   92.0   49.0  57.0
# 3       119       121   large  110.0   50.0    NaN    NaN   33.0  38.0
# 4       183       179  medium  138.0   80.0    NaN    NaN   44.0  41.0
#
#    time.ppn
# 0     720.0
# 1     360.0
# 2     180.0
# 3     480.0
# ...

# %% [markdown]
# # Explore the Data

# %%
# Calculating the number of missing values
missing = pd.concat([diabetes_data.isnull().sum(), 100 * diabetes_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'], ascending = False)
# Out:
#           count          %
# bp.2s       262  65.012407
# bp.2d       262  65.012407
# glyhb        13   3.225806
# frame        12   2.977667
# height        5   1.240695
# bp.1s         5   1.240695
# bp.1d         5   1.240695
# time.ppn      3   0.744417
# waist         2   0.496278
# hip           2   0.496278
# chol          1   0.248139
# hdl           1   0.248139
# ratio         1   0.248139
# weight        1   0.248139
# id            0   0.000000
# stab.glu      0   0.000000
# location      0   0.000000
# age           0   0.000000
# gender        0   0.000000

# %%
print(diabetes_data.columns)
# Out:
# Index(['id', 'chol', 'stab.glu', 'hdl', 'ratio', 'glyhb', 'location', 'age',
#        'gender', 'height', 'weight', 'frame', 'bp.1s', 'bp.1d', 'bp.2s',
#        'bp.2d', 'waist', 'hip', 'time.ppn'],
#       dtype='object')

# %%
# Calculating the number of missing values
missing = pd.concat([diabetes_registry.isnull().sum(), 100 * diabetes_registry.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'], ascending = False)
# Out:
#           count          %
# bp.2s       252  64.615385
# bp.2d       252  64.615385
# frame        11   2.820513
# bp.1s         5   1.282051
# bp.1d         5   1.282051
# Height        3   0.769231
# time.ppn      3   0.769231
# waist         2   0.512821
# hip           2   0.512821
# chol          1   0.256410
# hdl           1   0.256410
# ratio         1   0.256410
# id            0   0.000000
# stab.glu      0   0.000000
# glyhb         0   0.000000
# Location      0   0.000000
# Age           0   0.000000
# Gender        0   0.000000
# Weight 1      0   0.000000
# Weight 2      0   0.000000

# %%
print(diabetes_registry.columns)
# Out:
# Index(['id', 'chol', 'stab.glu', 'hdl', 'ratio', 'glyhb', 'Location', 'Age',
#        'Gender', 'Height', 'Weight 1', 'Weight 2', 'frame', 'bp.1s', 'bp.1d',
#        'bp.2s', 'bp.2d', 'waist', 'hip', 'time.ppn'],
#       dtype='object')

# %%
diabetes_data['id'].value_counts()
# Out:
# 1024     1
# 2757     1
# 4501     1
# 2770     1
# 10020    1
#         ..
# 17767    1
# 17766    1
# 17765    1
# 17762    1
# 1022     1
# Name: id, Length: 403, dtype: int64

# %%
diabetes_data.describe()
# Out:
#                  id        chol    stab.glu         hdl       ratio  \
# count    403.000000  402.000000  403.000000  402.000000  402.000000
# mean   15978.310174  207.845771  106.672457   50.445274    4.521642
# std    11881.122124   44.445557   53.076655   17.262626    1.727886
# min     1000.000000   78.000000   48.000000   12.000000    1.500000
# 25%     4792.500000  179.000000   81.000000   38.000000    3.200000
# 50%    15766.000000  204.000000   89.000000   46.000000    4.200000
# 75%    20336.000000  230.000000  106.000000   59.000000    5.400000
# max    41756.000000  443.000000  385.000000  120.000000   19.299999
#
#             glyhb         age      height      weight       bp.1s       bp.1d  \
# count  390.000000  403.000000  398.000000  402.000000  398.000000  398.000000
# mean     5.589769   46.851117   66.020101  177.592040  136.904523   83.321608
# std      2.242595   16.312333    3.918515   40.340666   22.741033   13.589227
# ...

# %%
diabetes_data.hist()
plt.subplots_adjust(hspace=0.8)

# %%
create_report(diabetes_data).show_browser()
# Out:
#   0%|                                                                                         | 0/3617 [00:00<…

# %%
create_report(diabetes_registry).show_browser()
# Out:
#   0%|                                                                                         | 0/3855 [00:00<…
